# %%
import torch

# %%
ts_1 = torch.randn(1, 2, 1)

print(ts_1)
print(ts_1.shape)
ts_1 = ts_1.unsqueeze(1)
print(ts_1.shape)
ts_1 = ts_1.squeeze(2)
print(ts_1.shape)
# Out:
# tensor([[[-2.0802],
#          [-0.8550]]])
# torch.Size([1, 2, 1])
# torch.Size([1, 1, 2, 1])
# torch.Size([1, 1, 2, 1])

# %%
ts_1 = torch.tensor([1, 2, 3])
ts_2 = torch.tensor([4, 5, 6])
ts_2 = ts_2.reshape(ts_2.shape[0], 1)

# %%
ts_3 = ts_1 + ts_2
print(ts_3)
# Out:
# tensor([[5, 6, 7],
#         [6, 7, 8],
#         [7, 8, 9]])
